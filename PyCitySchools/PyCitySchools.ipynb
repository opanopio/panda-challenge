# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "../Resources/schools_complete.csv"
student_data_to_load = "../Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# # District Summary

# %%
#Setting Dataframe
district_df=school_data_complete

# %%
#Total Number of Schools
school_total=len(district_df["school_name"].unique())

#Total Number of Students
student_count = school_data_complete["Student ID"].count()

#Total Budget
budget=district_df["budget"].unique().sum()

#Average Math Score
math_avg=district_df["math_score"].mean()

#Average Reading Score
read_avg=district_df["reading_score"].mean()

# % Passing Math 
pass_math=district_df.loc[district_df["math_score"]>=70]
pass_math_count = pass_math["Student ID"].count()
per_pass_math = (int(pass_math_count)/int(student_count))*100

# % Passing reading
pass_read=district_df.loc[district_df["reading_score"]>=70]
pass_read_count = pass_read["Student ID"].count()
per_pass_read = (int(pass_read_count)/int(student_count))*100

# % Overall Passing
overall_pass=district_df.loc[(district_df["reading_score"]>=70) & (district_df["math_score"]>=70),:]
overall_pass_count=overall_pass["Student ID"].count()
per_pass_overall = (int(overall_pass_count)/int(student_count))*100

# %%
#District Summary Table
district_summary_df=pd.DataFrame({"Total_Schools": [school_total],
                                "Total_Students": student_count,
                                "Total_Budget" : budget,
                                "Average_Math_Score": math_avg,
                                "Average_Reading_Score": read_avg,
                                "%_Passing_Math": per_pass_math,
                                "%_Passing Reading": per_pass_read,
                                "%_Overall Passing": per_pass_overall})
district_summary_df
# Out:
#    Total_Schools  Total_Students  Total_Budget  Average_Math_Score  \
# 0             15           39170      24649428           78.985371
#
#    Average_Reading_Score  %_Passing_Math  %_Passing Reading  %_Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# # School Summary

# %%
school_df=school_data_complete

# %%
#School Type
school_type=school_data.set_index(["school_name"])["type"]

#Total Students Per School
total_students=school_df["school_name"].value_counts()

#Budget Per School
total_school_budget=school_df.groupby(["school_name"]).mean()["budget"]

#Budget Per Student
budget_per_stu=total_school_budget/total_students

#Math Score Average Per School
school_math_avg=school_df.groupby(["school_name"]).mean()["math_score"]

#Reading Score Average Per School
school_read_avg=school_df.groupby(["school_name"]).mean()["reading_score"]

#% Passing Math Per School
school_pass_math=school_df.loc[school_df["math_score"]>=70]
school_pass_math_count = school_pass_math.groupby(["school_name"]).count()["student_name"]
school_per_pass_math = school_pass_math_count/total_students*100

#% Passing Reading Per School
school_pass_read=school_df.loc[school_df["reading_score"]>=70]
school_pass_read_count = school_pass_read.groupby(["school_name"]).count()["student_name"]
school_per_pass_read = school_pass_read_count/total_students*100

#% Overall Passing Per School
school_overall_pass=school_df.loc[(school_df["reading_score"]>=70) & (school_df["math_score"]>=70)]
school_per_pass_overall = school_overall_pass.groupby(["school_name"]).count() ["student_name"] /total_students*100

# %%
#School Summary Table
school_summary_df=pd.DataFrame({"School Type" : school_type,
                                "Total_Students": total_students,
                                "Total_Budget" : total_school_budget,
                                "Total_Budget_Per_Student" : budget_per_stu,
                                "Average_Math_Score": school_math_avg,
                                "Average_Reading_Score": school_read_avg,
                                "%_Passing_Math": school_per_pass_math,
                                "%_Passing_Reading": school_per_pass_read,
                                "%_Overall_Passing": school_per_pass_overall})
school_summary_df
# Out:
#                       School Type  Total_Students  Total_Budget  \
# Bailey High School       District            4976     3124928.0
# Cabrera High School       Charter            1858     1081356.0
# Figueroa High School     District            2949     1884411.0
# Ford High School         District            2739     1763916.0
# Griffin High School       Charter            1468      917500.0
# Hernandez High School    District            4635     3022020.0
# Holden High School        Charter             427      248087.0
# Huang High School        District            2917     1910635.0
# Johnson High School      District            4761     3094650.0
# Pena High School          Charter             962      585858.0
# Rodriguez High School    District            3999     2547363.0
# Shelton High School       Charter            1761     1056600.0
# Thomas High School        Charter            1635     1043130.0
# Wilson High School        Charter            2283     1319574.0
# ...

# %% [markdown]
# # Top Performing Schools (By % Overall Passing)

# %%
top_schools_df=school_summary_df.sort_values(["%_Overall_Passing"], ascending=False)
top_schools_df.head()
# Out:
#                     School Type  Total_Students  Total_Budget  \
# Cabrera High School     Charter            1858     1081356.0
# Thomas High School      Charter            1635     1043130.0
# Griffin High School     Charter            1468      917500.0
# Wilson High School      Charter            2283     1319574.0
# Pena High School        Charter             962      585858.0
#
#                      Total_Budget_Per_Student  Average_Math_Score  \
# Cabrera High School                     582.0           83.061895
# Thomas High School                      638.0           83.418349
# Griffin High School                     625.0           83.351499
# Wilson High School                      578.0           83.274201
# Pena High School                        609.0           83.839917
#
#                      Average_Reading_Score  %_Passing_Math  %_Passing_Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %% [markdown]
# # Bottom Performing Schools (By % Overall Passing)

# %%
bottom_schools_df=school_summary_df.sort_values(["%_Overall_Passing"], ascending=False)
bottom_schools_df.tail()
# Out:
#                       School Type  Total_Students  Total_Budget  \
# Johnson High School      District            4761     3094650.0
# Hernandez High School    District            4635     3022020.0
# Huang High School        District            2917     1910635.0
# Figueroa High School     District            2949     1884411.0
# Rodriguez High School    District            3999     2547363.0
#
#                        Total_Budget_Per_Student  Average_Math_Score  \
# Johnson High School                       650.0           77.072464
# Hernandez High School                     652.0           77.289752
# Huang High School                         655.0           76.629414
# Figueroa High School                      639.0           76.711767
# Rodriguez High School                     637.0           76.842711
#
#                        Average_Reading_Score  %_Passing_Math  \
# Johnson High School                80.966394       66.057551
# ...

# %% [markdown]
# # Math Scores by Grade

# %%
#9th Grade Math Scores
grade_9th=school_df.loc[school_df["grade"]=="9th"]
grade_9th_math=grade_9th.groupby(["school_name"]).mean()["math_score"]

#10th Grade Math Scores
grade_10th=school_df.loc[school_df["grade"]=="10th"]
grade_10th_math=grade_10th.groupby(["school_name"]).mean()["math_score"]

#11th Grade Math Scores
grade_11th=school_df.loc[school_df["grade"]=="11th"]
grade_11th_math=grade_11th.groupby(["school_name"]).mean()["math_score"]

#12th Grade Math Scores
grade_12th=school_df.loc[school_df["grade"]=="12th"]
grade_12th_math=grade_12th.groupby(["school_name"]).mean()["math_score"]

# %%
math_grade_summary_df=pd.DataFrame({"9th": grade_9th_math,
                                "10th" : grade_10th_math,
                                "11th" : grade_11th_math,
                                "12th": grade_12th_math})
math_grade_summary_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# # Reading Scores by Grade

# %%
#9th Grade Reading Scores
grade_9th_read=grade_9th.groupby(["school_name"]).mean()["reading_score"]

#10th Grade Reading Scores
grade_10th_read=grade_10th.groupby(["school_name"]).mean()["reading_score"]

#11th Grade Reading Scores
grade_11th_read=grade_11th.groupby(["school_name"]).mean()["reading_score"]

#12th Grade Reading Scores
grade_12th_read=grade_12th.groupby(["school_name"]).mean()["reading_score"]

# %%
read_grade_summary_df=pd.DataFrame({"9th": grade_9th_read,
                                "10th" : grade_10th_read,
                                "11th" : grade_11th_read,
                                "12th": grade_12th_read})
read_grade_summary_df
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# # Scores by School Spending

# %%
#Bins Setup
bins = [0, 585, 630, 645, 680 ]
group_names= ["<$585", "$585-630","$630-645", "$645-680"]

#Bin Code
school_summary_df["Spending Ranges (Per Student)"]=pd.cut(school_summary_df["Total_Budget_Per_Student"], bins, labels=group_names, include_lowest=True)

#Final Chart
scores_by_spend=school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()[["Average_Math_Score", "Average_Reading_Score","%_Passing_Math","%_Passing_Reading","%_Overall_Passing"]]
scores_by_spend
# Out:
#                                Average_Math_Score  Average_Reading_Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-630                                81.899826              83.155286
# $630-645                                78.518855              81.624473
# $645-680                                76.997210              81.027843
#
#                                %_Passing_Math  %_Passing_Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-630                            87.133538          92.718205
# $630-645                            73.484209          84.391793
# $645-680                            66.164813          81.133951
#
#                                %_Overall_Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-630                               81.418596
# ...

# %% [markdown]
# # Scores by School Size

# %%
#Bins Setup
bins = [0, 1000, 2000, 5000]
group_names= ["Small (<1000)", "Medium (1000-2000)","Large (2000-5000)"]

#Bin Code
school_summary_df["School Size"]=pd.cut(school_summary_df["Total_Students"], bins, labels=group_names, include_lowest=True)

#Final Chart
scores_by_spend=school_summary_df.groupby(["School Size"]).mean()[["Average_Math_Score", "Average_Reading_Score","%_Passing_Math","%_Passing_Reading","%_Overall_Passing"]]
scores_by_spend
# Out:
#                     Average_Math_Score  Average_Reading_Score  %_Passing_Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     %_Passing_Reading  %_Overall_Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %%
#Final Chart
scores_by_spend=school_summary_df.groupby(["School Type"]).mean()[["Average_Math_Score", "Average_Reading_Score","%_Passing_Math","%_Passing_Reading","%_Overall_Passing"]]
scores_by_spend
# Out:
#              Average_Math_Score  Average_Reading_Score  %_Passing_Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              %_Passing_Reading  %_Overall_Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
